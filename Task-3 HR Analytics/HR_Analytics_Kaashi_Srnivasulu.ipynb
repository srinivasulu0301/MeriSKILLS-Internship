# %% [markdown]
# # HR Analytics - Project 3
# ## Kaashi Srinivauslu
# ## MeriSKILL!

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('HR-Employee-Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## Tasks to perform

# %% [markdown]
# #### Data Cleaning
# * Deleting Redundent Columns
# * Renaming the columns
# * Dropping duplicates
# * Cleaning Individual columns
# * Removing NaN values from dataset

# %%
# dropping the duplicates from dataset
df= df.drop_duplicates()

# %%
# removing the NaN values
df = df.dropna()

# %% [markdown]
# #### Data Vusialization
# * Plot of correlation map for all numeric values

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Overtime

# %%
sns.countplot(df['OverTime'])
plt.title('Over Time')
plt.show()

# %% [markdown]
# * Most of the employees prefer not to work overtime
# ***
# ***

# %% [markdown]
# ##### Marital Status

# %%
sns.countplot(df['MaritalStatus'])
plt.title('Marital Status')
plt.show()

# %% [markdown]
# * Employees are mostly married or single
# ****
# ****

# %% [markdown]
# ##### Job Role

# %%
sns.countplot(df['JobRole'])
plt.title('Job Role')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# * Sales team has highest number of employees and HR team with least
# ***
# ***

# %% [markdown]
# ##### Gender

# %%
sns.countplot(df['Gender'])
plt.title('Gender')
plt.show()

# %% [markdown]
# * Number of Male employees are relatively more when comapred to female employees
# ***
# ***

# %% [markdown]
# ##### Education Field

# %%
sns.countplot(df['EducationField'])
plt.title('Education Field')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * Employees are moslty from Life sciences or medical as their educaiton background
# ***
# ***

# %% [markdown]
# ##### Department

# %%
sns.countplot(df['Department'])
plt.title('Department')
plt.show()

# %% [markdown]
# * R&D Department has highest number of employee count followed by sales department
# ***
# ***

# %% [markdown]
# ##### Business Travel

# %%
sns.countplot(df['BusinessTravel'])
plt.title('Business Travel')
plt.show()

# %% [markdown]
# * There are business travel very rarely or else no travel
# ***
# ***

# %% [markdown]
# ##### Relation Between overtime and age

# %%
sns.boxplot(df['Age'],df['OverTime'])
plt.title('Realtion between overtime and age')
plt.show()

# %% [markdown]
# * Thought he age range of overtime and non-overtime employees is same the median age of overtime employees is slightly higher
# ***
# ***

# %% [markdown]
# ##### Total Woking years

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['TotalWorkingYears'])
plt.title('Total Working Years')
plt.show()

# %% [markdown]
# * The work experince of employees with 10 years are most in the company followed by 6 and 8 years of experience
# ***
# ***

# %% [markdown]
# ##### Education Level

# %%
sns.countplot(df['Education'])
plt.title('Educaiton Level')
plt.show()

# %% [markdown]
# * Mostly employees are of level 3 or 4 on education
# ***
# ***

# %% [markdown]
# ##### Number of Companies worked

# %%
sns.countplot(df['NumCompaniesWorked'])
plt.title('Number of companies worked')
plt.show()

# %% [markdown]
# * There more number number of employees with number of companies they have worked as 1
# ***
# ***

# %% [markdown]
# ##### Distance from home

# %%
sns.displot(df['DistanceFromHome'])
plt.title('Distance from home')
plt.show()

# %% [markdown]
# * The distance from home to office is very near for most of the emoloyees
# ***
# ***

# %%
# Income by job role
sns.boxplot(df['JobRole'],df['MonthlyIncome'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * The monthly income of Managers ans Research Directors are highest and Sales representatives are lowest
